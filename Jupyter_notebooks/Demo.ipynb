# %%
from __future__ import absolute_import, division, print_function

import numpy as np
import sys
import matplotlib.pyplot as plt
from keras.models import load_model

sys.path.append('..')
from defectfinder import gridsearch as gs

# %%
x_train=np.load(".././dataset/dataset_noise/x_train.npy")
x_test=np.load(".././dataset/dataset_noise/x_test.npy")
y_train=np.load(".././dataset/dataset_noise/y_train.npy")
y_test=np.load(".././dataset/dataset_noise/y_test.npy")

# %%
imagenumber=395
plt.imshow(np.reshape(x_test[imagenumber],(64,64)),cmap='gray')

# %%
model=load_model("../HyperparametersTuning/learn_rate_narrow_AdamM31/model1.h5")

# %%
heatmap=gs.visualize_class_activation_map(model, x_test[imagenumber])
# Out:
# predicted defect type:
# Vs2
# coordinates:
# [(63.0, 63.0), (31.0, 0.0), (0.0, 63.0)]

# %% [markdown]
# * defectslist: 'Sw','Mo','W2s2','Vw','Vs2','Ws'

# %%
y_test[imagenumber]
# Out:
# array([0., 0., 0., 0., 1., 0.], dtype=float32)
